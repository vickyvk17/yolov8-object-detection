# %%
# !pip install ultralytics opencv-python numpy

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
train = "/content/drive/MyDrive/Colab Notebooks/metal_holes_dataset/train/images"
val = "/content/drive/MyDrive/Colab Notebooks/metal_holes_dataset/val/images"

# %%
# Load a pretrained model
model = YOLO('yolov8n.pt')

dataset_yaml_content = f"""
train: {train}
val: {val}
nc: 2  # Number of classes
names: ['Holes', 'Threaded_Holes'] # Class names
"""

with open('dataset.yaml', 'w') as f:
    f.write(dataset_yaml_content)

# Train the model
results = model.train(
    data='dataset.yaml',
    epochs=50,
    imgsz=640,
    batch=8,
    name='metal_holes_detection'
)
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo predict model=/content/runs/detect/metal_holes_detection5/weights/best.pt source='/content/118_image.jpg' save_txt=True save_conf=True
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/118_image.jpg: 640x640 3 Holess, 9 Threaded_Holess, 241.7ms
# Speed: 7.8ms preprocess, 241.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
import cv2
import json
import os

# %%
def detect_holes_and_export_json(model_path, image_folder, output_json_path):

    model = YOLO(model_path)

    results_dict = {}


    for img_name in os.listdir(image_folder):
        if not img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        img_path = os.path.join(image_folder, img_name)
        img = cv2.imread(img_path)


        results = model(img)


        detections = []
        for result in results:
            for box in result.boxes:

                class_id = int(box.cls)
                class_name = model.names[class_id]
                confidence = float(box.conf)
                x1, y1, x2, y2 = map(int, box.xyxy[0])


                center_x = (x1 + x2) / 2
                center_y = (y1 + y2) / 2

                detections.append({
                    "class": class_name,
                    "confidence": confidence,
                    "bbox": [x1, y1, x2, y2],
                    "center": [center_x, center_y]
                })


        hole_count = sum(1 for d in detections if d["class"] == "Holes")
        threaded_hole_count = sum(1 for d in detections if d["class"] == "Threaded_Holes")



        results_dict[img_name] = {
            "total_holes": hole_count,
            "total_threaded_holes": threaded_hole_count,
            "detections": detections
        }


    with open(output_json_path, 'w') as f:
        json.dump(results_dict, f, indent=4)

    print(f"Results saved to {output_json_path}")


detect_holes_and_export_json(
    model_path='/content/runs/detect/metal_holes_detection5/weights/best.pt',  # your trained model
    image_folder='/content/', # Assuming the image is in the content folder based on previous cells
    output_json_path='holes_detection_results.json'
)
# Out:
# 0: 640x640 3 Holess, 9 Threaded_Holess, 249.5ms
# Speed: 5.3ms preprocess, 249.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 64 Holess, 167.8ms
# Speed: 5.8ms preprocess, 167.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 71 Holess, 164.7ms
# Speed: 5.1ms preprocess, 164.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to holes_detection_results.json
